# %%
import pandas as pd 
import numpy as np

# %%
mr = pd.read_excel("..\Data\Tabular\All_Raagams.xlsx")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\vishg\AppData\Local\Temp\ipykernel_17400\3379684453.py:1: SyntaxWarning: invalid escape sequence '\D'
#   mr = pd.read_excel("..\Data\Tabular\All_Raagams.xlsx")

# %%
mr = mr[mr['Melakarta']==1]
mr['path'] = mr['AAROHANAM'].apply(lambda x: x.replace("\xa0","-"))
mr['value'] = 1
mr.to_csv("..\Data\Tabular\Melakarta_Raagams.csv", index = False)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\vishg\AppData\Local\Temp\ipykernel_17400\2243583307.py:4: SyntaxWarning: invalid escape sequence '\D'
#   mr.to_csv("..\Data\Tabular\Melakarta_Raagams.csv", index = False)

# %%
mr
# Out:
#                  Raga Name Raw                Raga Name             AAROHANAM  \
# 0    1 Kanakāngi (Janaka raga)  Kanakāngi (Janaka raga)  S R1 G1 M1 P D1 N1 S
# 13                  2 Ratnāngi                 Ratnāngi  S R1 G1 M1 P D1 N2 S
# 21                 3 Gānamūrti                Gānamūrti  S R1 G1 M1 P D1 N3 S
# 27                 4 Vanaspati                Vanaspati  S R1 G1 M1 P D2 N2 S
# 32                  5 Mānavati                 Mānavati  S R1 G1 M1 P D2 N3 S
# ..                         ...                      ...                   ...
# 954         68 Jyothisvarūpiṇi          Jyothisvarūpiṇi  S R3 G3 M2 P D1 N2 S
# 959           69 Dhātuvardhani            Dhātuvardhani  S R3 G3 M2 P D1 N3 S
# 964           70 Nāsikābhūśaṇi            Nāsikābhūśaṇi  S R3 G3 M2 P D2 N2 S
# 968                 71 Kōsalam                  Kōsalam  S R3 G3 M2 P D2 N3 S
# 971             72 Rasikapriyā              Rasikapriyā  S R3 G3 M2 P D3 N3 S
#
# ...

# %%
mr
# Out:
#                  Raga Name Raw                Raga Name             AAROHANAM  \
# 0    1 Kanakāngi (Janaka raga)  Kanakāngi (Janaka raga)  S R1 G1 M1 P D1 N1 S
# 13                  2 Ratnāngi                 Ratnāngi  S R1 G1 M1 P D1 N2 S
# 21                 3 Gānamūrti                Gānamūrti  S R1 G1 M1 P D1 N3 S
# 27                 4 Vanaspati                Vanaspati  S R1 G1 M1 P D2 N2 S
# 32                  5 Mānavati                 Mānavati  S R1 G1 M1 P D2 N3 S
# ..                         ...                      ...                   ...
# 954         68 Jyothisvarūpiṇi          Jyothisvarūpiṇi  S R3 G3 M2 P D1 N2 S
# 959           69 Dhātuvardhani            Dhātuvardhani  S R3 G3 M2 P D1 N3 S
# 964           70 Nāsikābhūśaṇi            Nāsikābhūśaṇi  S R3 G3 M2 P D2 N2 S
# 968                 71 Kōsalam                  Kōsalam  S R3 G3 M2 P D2 N3 S
# 971             72 Rasikapriyā              Rasikapriyā  S R3 G3 M2 P D3 N3 S
#
# ...

# %%
print([i for i in mr.iloc[1,-2]])
# Out:
# ['S', '-', 'R', '1', '-', 'G', '1', '-', 'M', '1', '-', 'P', '-', 'D', '1', '-', 'N', '2', '-', 'S']
